# %%
# Run
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import os, sys
sys.path.append('..')
from field import *

# %%
parent_path = '../../../' # How many folders do you have to go back before you are out of the P: drive?

path_MS = 'L:/PG-Nanoteknologi/PROJEKTER/EPA-asfaltprojekt/On-line PAH Projekt KU/ACSM/txt/mass_spec/'

MS = read_MS_txt(path_MS, parent_path)
display(MS.keys())
display(MS['Trafic_before'].keys())
# Out:
# dict_keys(['Trafic_before', 'Asphalt_peak', 'After_AP', 'Trafic_after'])
# Index(['mass', 'Greve 28062023', 'Indiakaj 13072022', 'Indiakaj 14072022',
#        'Vesterbrogade 12062023', 'Vesterbrogade 13062023'],
#       dtype='object')

# %%
fig, ax = plt.subplots(5, 1, figsize = (8, 12))

for i in ax:
    i.set(xlim = (100, 305))

plot_MS(ax[0], MS['Trafic_before'], 'Indiakaj 13072022', 'Indiakaj 13072022')
ax[0].set_ylim(0, 0.01)
plot_MS(ax[1], MS['Trafic_before'], 'Indiakaj 14072022', 'Indiakaj 14072022')
ax[1].set_ylim(0, 0.002)
plot_MS(ax[2], MS['Trafic_before'], 'Vesterbrogade 12062023', 'Vesterbrogade 12062023')
ax[2].set_ylim(0, 0.01)
plot_MS(ax[3], MS['Trafic_before'], 'Vesterbrogade 13062023', 'Vesterbrogade 13062023')
ax[3].set_ylim(0, 0.01)
plot_MS(ax[4], MS['Trafic_before'], 'Greve 28062023', 'Greve 13062023')
ax[4].set_ylim(0, 0.007)

fig.tight_layout()
fig.savefig('Field_data/TraficBefore_MS_100-305.png', dpi = 600)
plt.show()

# %%
fig, ax = plt.subplots(5, 1, figsize = (8, 12))

for i in ax:
    i.set(xlim = (100, 305))

plot_MS(ax[0], MS['Asphalt_peak'], 'Indiakaj 13072022', 'Indiakaj 13072022')
ax[0].set_ylim(0, 0.1)
plot_MS(ax[1], MS['Asphalt_peak'], 'Indiakaj 14072022', 'Indiakaj 14072022')
ax[1].set_ylim(0, 0.025)
plot_MS(ax[2], MS['Asphalt_peak'], 'Vesterbrogade 12062023', 'Vesterbrogade 12062023')
ax[2].set_ylim(0, 0.7)
plot_MS(ax[3], MS['Asphalt_peak'], 'Vesterbrogade 13062023', 'Vesterbrogade 13062023')
ax[3].set_ylim(0, 2.7)
plot_MS(ax[4], MS['Asphalt_peak'], 'Greve 28062023', 'Greve 13062023')
ax[4].set_ylim(0, 0.9)

fig.tight_layout()
fig.savefig('Field_data/Asphalt_MS_100-305.png', dpi = 600)
plt.show()

# %%
fig, ax = plt.subplots(5, 1, figsize = (8, 12))

for i in ax:
    i.set(xlim = (100, 305))

plot_MS(ax[0], MS['After_AP'], 'Indiakaj 13072022', 'Indiakaj 13072022')
ax[0].set_ylim(0, 0.07)
plot_MS(ax[1], MS['After_AP'], 'Indiakaj 14072022', 'Indiakaj 14072022')
ax[1].set_ylim(0, 0.015)
plot_MS(ax[2], MS['After_AP'], 'Vesterbrogade 12062023', 'Vesterbrogade 12062023')
ax[2].set_ylim(0, 0.13)
plot_MS(ax[3], MS['After_AP'], 'Vesterbrogade 13062023', 'Vesterbrogade 13062023')
ax[3].set_ylim(0, 0.2)
plot_MS(ax[4], MS['After_AP'], 'Greve 28062023', 'Greve 13062023')
ax[4].set_ylim(0, 0.06)

fig.tight_layout()
fig.savefig('Field_data/AfterAP_MS_100-305.png', dpi = 600)
plt.show()

# %%
fig, ax = plt.subplots(5, 1, figsize = (8, 12))

for i in ax:
    i.set(xlim = (100, 305))

plot_MS(ax[0], MS['Trafic_after'], 'Indiakaj 13072022', 'Indiakaj 13072022')
ax[0].set_ylim(0, 0.009)
plot_MS(ax[1], MS['Trafic_after'], 'Indiakaj 14072022', 'Indiakaj 14072022')
ax[1].set_ylim(0, 0.002)
plot_MS(ax[2], MS['Trafic_after'], 'Vesterbrogade 12062023', 'Vesterbrogade 12062023')
ax[2].set_ylim(0, 0.016)
plot_MS(ax[3], MS['Trafic_after'], 'Vesterbrogade 13062023', 'Vesterbrogade 13062023')
ax[3].set_ylim(0, 0.012)
plot_MS(ax[4], MS['Trafic_after'], 'Greve 28062023', 'Greve 13062023')
ax[4].set_ylim(0, 0.007)

fig.tight_layout()
fig.savefig('Field_data/TraficAfter_MS_100-305.png', dpi = 600)
plt.show()

# %%
fig, ax = plt.subplots(4, 1, figsize = (8, 10))

plot_MS(ax[0], MS['Trafic_before'], 'Vesterbrogade 13062023', 'Trafic before')
plot_MS(ax[1], MS['Asphalt_peak'], 'Vesterbrogade 13062023', 'Asphalt peak')
plot_MS(ax[2], MS['After_AP'], 'Vesterbrogade 13062023', 'After asphalt peak')
plot_MS(ax[3], MS['Trafic_after'], 'Vesterbrogade 13062023', 'Trafic after')
ax[0].set(xlim = (100, 305), ylim = (0, 0.009), title = 'Traffic before')
ax[1].set(xlim = (100, 305), ylim = (0, 2.7))
ax[2].set(xlim = (100, 305), ylim = (0, 0.2))
ax[3].set(xlim = (100, 305), ylim = (0, 0.011), title = 'Traffic after')

fig.tight_layout()
fig.savefig('Field_data/13062023_MS_100-305.png', dpi = 600)
plt.show()

# %%
fig, ax = plt.subplots(4, 1, figsize = (8, 10))

plot_MS(ax[0], MS['Trafic_before'], 'Vesterbrogade 13062023', 'Trafic before')
plot_MS(ax[1], MS['Asphalt_peak'], 'Vesterbrogade 13062023', 'Asphalt peak')
plot_MS(ax[2], MS['After_AP'], 'Vesterbrogade 13062023', 'After asphalt peak')
plot_MS(ax[3], MS['Trafic_after'], 'Vesterbrogade 13062023', 'Trafic after')
ax[0].set(xlim = (40, 305), ylim = (0, 0.9))
ax[1].set(xlim = (40, 305), ylim = (0, 15))
ax[2].set(xlim = (40, 305), ylim = (0, 1.5))
ax[3].set(xlim = (40, 305), ylim = (0, 0.9))

fig.tight_layout()
fig.savefig('Field_data/13062023_MS_40-305.png', dpi = 600)
plt.show()
